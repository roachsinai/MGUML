# %% [markdown]
# ## Linear Regression

# %% [markdown]
# **Here is just a small test about does scaling is important in linear regression**.

# %%
print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
# %load_ext watermark
# %watermark -a 'RoachSiani' -d -p numpy,sklearn,matplotlib -v
# Out:
# RoachSiani 2016-08-27
#
# CPython 3.5.2
# IPython 5.1.0
#
# numpy 1.11.0
# sklearn 0.17.1
# matplotlib 1.5.1

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import datasets

# %%
# make data: sample has two features.

data_X, data_Y = datasets.make_regression(n_samples=50,n_features=2,n_informative=1,noise=10,random_state=10)

# %%
from sklearn import linear_model

clf = linear_model.LinearRegression();
clf.fit(data_X, data_Y)
predict_Y = clf.predict(data_X)

print(data_X[0:10,:])

print('##########################')

# The coefficients
print('Coefficients: \n', clf.coef_)
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((clf.predict(data_X) - data_Y) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % clf.score(data_X, data_Y))
# Out:
# [[ 0.61320418 -0.27124799]
#  [-0.54930901 -0.26731719]
#  [ 1.67262221  1.12369125]
#  [-0.2227737  -1.85618548]
#  [ 0.24454398  1.10770823]
#  [-0.00838385 -1.54540029]
#  [ 0.62060066 -1.50832149]
#  [-0.52929608 -0.08112218]
#  [-0.72008556  0.62133597]
#  [-1.95451212  0.82699862]]
# ##########################
# Coefficients:
#  [ -0.41823939  31.01186166]
# Residual sum of squares: 86.83
# Variance score: 0.90

# %%
# %matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(data_X[:,0],data_X[:,1],data_Y)
ax.scatter(data_X[:,0],data_X[:,1],predict_Y,c='r')

# %% [markdown]
# ## Change magnitude

# %%
data_X[:,0] *= 10

clf = linear_model.LinearRegression();
clf.fit(data_X, data_Y)
predict_Y = clf.predict(data_X)

print(data_X[0:10,:])

print('##########################')

# The coefficients
print('Coefficients: \n', clf.coef_)
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((clf.predict(data_X) - data_Y) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % clf.score(data_X, data_Y))
# Out:
# [[  6.13204185  -0.27124799]
#  [ -5.49309014  -0.26731719]
#  [ 16.72622213   1.12369125]
#  [ -2.22773699  -1.85618548]
#  [  2.44543977   1.10770823]
#  [ -0.0838385   -1.54540029]
#  [  6.20600663  -1.50832149]
#  [ -5.29296081  -0.08112218]
#  [ -7.20085561   0.62133597]
#  [-19.5451212    0.82699862]]
# ##########################
# Coefficients:
#  [ -0.04182394  31.01186166]
# Residual sum of squares: 86.83
# Variance score: 0.90

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(data_X[:,0],data_X[:,1],data_Y)
ax.scatter(data_X[:,0],data_X[:,1],predict_Y,c='r')

# %% [markdown]
# **We can found scaling doesn't matter in linear regression. It just change the weight of each feature**.

# %%
print(np.corrcoef(data_X[:,0], data_X[:,1]))
# Out:
# [[ 1.          0.15199435]
#  [ 0.15199435  1.        ]]
